# %%
weather = weather = pd.read_csv("weather_imputation.csv")

station = weather[weather['station_nbr'] == 18]
station.reset_index(drop=True, inplace=True)
station.tail()
# Out:
#       station_nbr        date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 1030           18  2014-10-27  85.0  67.0  76.0    12.0      59.0     65.0
# 1031           18  2014-10-28  79.0  66.0  73.0     9.0      58.0     64.0
# 1032           18  2014-10-29  77.0  56.0  67.0     3.0      46.0     56.0
# 1033           18  2014-10-30  79.0  56.0  68.0     5.0      51.0     58.0
# 1034           18  2014-10-31  67.0  49.0  58.0    -4.0      40.0     50.0
#
#       heat  cool ...   snowfall  preciptotal stnpressure  sealevel  \
# 1030   0.0  11.0 ...        0.0        0.000       29.31     29.82
# 1031   0.0   8.0 ...        0.0        0.000       29.50     29.98
# 1032   0.0   2.0 ...        0.0        0.000       29.62     30.13
# 1033   0.0   3.0 ...        0.0        0.005       29.60     30.11
# 1034   7.0   0.0 ...        0.0        0.000       29.78     30.28
#
#       resultspeed  resultdir  avgspeed  year  month  day
# 1030         14.9       19.0      15.3  2014     10   27
# 1031          2.6        2.0       8.2  2014     10   28
# 1032          5.1        9.0       6.8  2014     10   29
# 1033          2.9       14.0       5.6  2014     10   30
# 1034         10.6       36.0      11.2  2014     10   31
#
# [5 rows x 23 columns]

# %%
station['date'] = pd.to_datetime(station['date'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 2 ( 0.19 % )
# tmin : 2 ( 0.19 % )
# tavg : 4 ( 0.39 % )
# depart : 34 ( 3.29 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 3 ( 0.29 % )
# heat : 4 ( 0.39 % )
# cool : 4 ( 0.39 % )
# sunrise : 31 ( 3.0 % )
# sunset : 31 ( 3.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 5 ( 0.48 % )
# preciptotal : 2 ( 0.19 % )
# stnpressure : 5 ( 0.48 % )
# sealevel : 2 ( 0.19 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 0 ( 0.0 % )
# avgspeed : 2 ( 0.19 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %% [markdown]
# ##### finding : tavg, heat, cool
# - tavg = (tmin + tmax) / 2
# - 65 - heat = tavg
# - 65 + cool = tavg

# %% [markdown]
# ##### tmax와 tmin의 평균을 tavg에 넣어준다.

# %%
# tmax와 tmin의 평균을 tavg에 넣어준다.
station['tavg'] = (station.tmax + station.tmin) / 2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### heat = 65 - tavg 대입

# %%
# heat = 65 - tavg
idx = station[station.heat.isna()].index
station.loc[idx,'heat'] = 65 - station.loc[idx,'tavg']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ##### # cool = tavg - 65

# %%
# cool = tavg - 65
idx = station[station.cool.isna()].index
station.loc[idx,'cool'] = station.loc[idx,'tavg'] - 65
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 2 ( 0.19 % )
# tmin : 2 ( 0.19 % )
# tavg : 2 ( 0.19 % )
# depart : 34 ( 3.29 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 3 ( 0.29 % )
# heat : 2 ( 0.19 % )
# cool : 2 ( 0.19 % )
# sunrise : 31 ( 3.0 % )
# sunset : 31 ( 3.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 5 ( 0.48 % )
# preciptotal : 2 ( 0.19 % )
# stnpressure : 5 ( 0.48 % )
# sealevel : 2 ( 0.19 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 0 ( 0.0 % )
# avgspeed : 2 ( 0.19 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %% [markdown]
# #### NaN값 : 해당 월의 평균값을 집어넣는다.
# - column의 index를 뽑는다.
# - index의 year와 month를 뽑는다.
# - 해당 nan값의 year, month column평균을 낸다.
# - 적용 후 tavg, heat, cool을 구한다.

# %%
# idxs = station[station['depart'].isna().values].index
# year = station.loc[idxs[0],'year']
# month = station.loc[idxs[0],'month']
# year, month

# %%
# ym = station[station['year']==year][station['month']==month]
# station.loc[idxs[0],'depart'] = ym['depart'].mean()

# %% [markdown]
# ### 여러 column에 적용해보자

# %%
for column in station.columns[2:8]:
    idxs = station[station[column].isna().values].index
    for idx in idxs:
        year = station.loc[idx,'year']
        month = station.loc[idx,'month']
        ym = station[station['year']==year][station['month']==month]
        station.loc[idx,column] = ym[column].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 31 ( 3.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 2 ( 0.19 % )
# cool : 2 ( 0.19 % )
# sunrise : 31 ( 3.0 % )
# sunset : 31 ( 3.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 5 ( 0.48 % )
# preciptotal : 2 ( 0.19 % )
# stnpressure : 5 ( 0.48 % )
# sealevel : 2 ( 0.19 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 0 ( 0.0 % )
# avgspeed : 2 ( 0.19 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %% [markdown]
# ##### 한번더  더해준다 : tavg, heat, cool
# - tavg = (tmin + tmax) / 2
# - 65 - heat = tavg
# - 65 + cool = tavg

# %%
# heat = 65 - tavg
idx = station[station.heat.isna()].index
station.loc[idx,'heat'] = 65 - station.loc[idx,'tavg']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ##### # cool = tavg - 65

# %%
# cool = tavg - 65
idx = station[station.cool.isna()].index
station.loc[idx,'cool'] = station.loc[idx,'tavg'] - 65
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for column in station.columns[13:18]:
    idxs = station[station[column].isna().values].index
    for idx in idxs:
        year = station.loc[idx,'year']
        month = station.loc[idx,'month']
        ym = station[station['year']==year][station['month']==month]
        station.loc[idx,column] = ym[column].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 31 ( 3.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 0 ( 0.0 % )
# cool : 0 ( 0.0 % )
# sunrise : 31 ( 3.0 % )
# sunset : 31 ( 3.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 0 ( 0.0 % )
# preciptotal : 0 ( 0.0 % )
# stnpressure : 0 ( 0.0 % )
# sealevel : 0 ( 0.0 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 0 ( 0.0 % )
# avgspeed : 2 ( 0.19 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %%
for column in station.columns[19:20]:
    idxs = station[station[column].isna().values].index
    for idx in idxs:
        year = station.loc[idx,'year']
        month = station.loc[idx,'month']
        ym = station[station['year']==year][station['month']==month]
        station.loc[idx,column] = ym[column].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 31 ( 3.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 0 ( 0.0 % )
# cool : 0 ( 0.0 % )
# sunrise : 31 ( 3.0 % )
# sunset : 31 ( 3.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 0 ( 0.0 % )
# preciptotal : 0 ( 0.0 % )
# stnpressure : 0 ( 0.0 % )
# sealevel : 0 ( 0.0 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 0 ( 0.0 % )
# avgspeed : 0 ( 0.0 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %%
station.to_csv("station18_monthmean.csv", index=False)

# %%
cols = ['tmax','tmin','tavg','dewpoint','wetbulb','heat','cool','preciptotal','stnpressure','sealevel','resultspeed','avgspeed']
sns.pairplot(station[cols])
plt.show()
