# %%
train = pd.read_csv("data/train.csv")
train.tail()
# Out:
#                date  store_nbr  item_nbr  units
# 4617595  2014-10-31         45       107      0
# 4617596  2014-10-31         45       108      0
# 4617597  2014-10-31         45       109      0
# 4617598  2014-10-31         45       110      0
# 4617599  2014-10-31         45       111      0

# %%
df = train[train.units > 0].reset_index(drop=True)
df.tail()
# Out:
#               date  store_nbr  item_nbr  units
# 118691  2014-10-31         44         5     47
# 118692  2014-10-31         44        68     39
# 118693  2014-10-31         44        94      1
# 118694  2014-10-31         45         9     10
# 118695  2014-10-31         45        26      1

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
year = [pd.to_datetime(df["date"].values[i], format="%y%m%d", errors='ignore').year for i in range(len(df))]
df['year'] = year

# %%
df_2012 = df[df['year'] == 2012]

# %%
key = pd.read_csv('data/key.csv')

# %%
key.tail()
# Out:
#     store_nbr  station_nbr
# 40         41           12
# 41         42           14
# 42         43           11
# 43         44           12
# 44         45           16

# %%
df2 = df.merge(key)

# %%
df3 = df2.pivot_table(index='year', columns=['station_nbr','store_nbr','item_nbr'], values='units', aggfunc=sum, fill_value=0)

# %%
df4 = df3[17].T

# %%
df4[2012].reset_index()
# Out:
#     store_nbr  item_nbr   2012
# 0           9         5  21602
# 1           9        10    363
# 2           9        42   2680
# 3           9        45  28287
# 4           9        93    906
# 5           9       105      0
# 6          18         5   6798
# 7          18        37   3729
# 8          18        57    119
# 9          18        72    215
# 10         23         5  12074
# 11         23        29    290
# 12         23        45  13103
# 13         23        56    429
# 14         26         2    382
# 15         26         5  22890
# 16         26        45  18799
# 17         31         9  18711
# 18         31        45  30633
# 19         31        67   1893
# 20         31        93    739
# 21         31        98    160
# 22         31       104      0
# 23         34         9  18981
# 24         34        31    273
# 25         34        45  38022
# 26         34        52    623
# 27         34        84     35
# 28         34        93    428

# %%
weather = pd.read_csv("./weather3_180703.csv")
weather['date'] = pd.to_datetime(weather["date"])
station = weather[weather['station_nbr'] == 3]

# %%
station.tail()
# Out:
#       station_nbr       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 3100            3 2014-10-27  82.0  66.0  74.0    16.0      57.0     63.0
# 3101            3 2014-10-28  70.0  47.0  58.5     1.0      44.0     51.0
# 3102            3 2014-10-29  73.0  41.0  57.0     0.0      42.0     50.0
# 3103            3 2014-10-30  78.0  51.0  64.5     9.0      41.0     51.0
# 3104            3 2014-10-31  55.0  33.0  44.0   -12.0      32.0     41.0
#
#       heat  cool   ...     day  relative_humility  windchill    daytime  \
# 3100   0.0   9.0   ...      27          55.370380  75.318476  10.866667
# 3101   6.0   0.0   ...      28          58.502023  57.570552  10.833333
# 3102   8.0   0.0   ...      29          57.184861  57.822427  10.800000
# 3103   0.0   0.0   ...      30          42.166793  63.970968  10.766667
# 3104  21.0   0.0   ...      31          62.465729  38.046534  10.733333
#
#       week7  weekend  code_change  rainY  otherY  nothing
# ...

# %%
train = pd.read_csv("./data/train.csv")
train.date = pd.to_datetime(train.date)
train.tail()
# Out:
#               date  store_nbr  item_nbr  units
# 4617595 2014-10-31         45       107      0
# 4617596 2014-10-31         45       108      0
# 4617597 2014-10-31         45       109      0
# 4617598 2014-10-31         45       110      0
# 4617599 2014-10-31         45       111      0

# %%
key = pd.read_csv("./data/key.csv")
station = station.merge(key)

# %%
station = station.merge(train)
station.tail()
# Out:
#         station_nbr       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 304357            3 2014-10-31  55.0  33.0  44.0   -12.0      32.0     41.0
# 304358            3 2014-10-31  55.0  33.0  44.0   -12.0      32.0     41.0
# 304359            3 2014-10-31  55.0  33.0  44.0   -12.0      32.0     41.0
# 304360            3 2014-10-31  55.0  33.0  44.0   -12.0      32.0     41.0
# 304361            3 2014-10-31  55.0  33.0  44.0   -12.0      32.0     41.0
#
#         heat  cool  ...      daytime  week7 weekend  code_change  rainY  \
# 304357  21.0   0.0  ...    10.733333      4       0            0      0
# 304358  21.0   0.0  ...    10.733333      4       0            0      0
# 304359  21.0   0.0  ...    10.733333      4       0            0      0
# 304360  21.0   0.0  ...    10.733333      4       0            0      0
# 304361  21.0   0.0  ...    10.733333      4       0            0      0
#
#         otherY  nothing  store_nbr  item_nbr  units
# ...

# %%
df = station.pivot_table(index=['store_nbr'], columns='item_nbr', values='units', aggfunc=np.sum)

# %%
df1 = df.replace(0,np.nan)

# %%
df3 = df1.dropna(how='all', axis=1)

# %%
df3.fillna(value=0, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df3 # station3
# Out:
# item_nbr            5        8        9       41       44       45     56   \
# store_nbr year
# 21        2012  16100.0      0.0      0.0     0.0  29364.0      0.0    0.0
#           2013  15868.0      0.0      0.0     0.0  24776.0      0.0    0.0
#           2014   9673.0      0.0      0.0     0.0  15449.0      0.0    0.0
# 29        2012      0.0  12969.0      0.0  9290.0      0.0  27185.0  325.0
#           2013      0.0  10472.0      0.0  6571.0      0.0  18863.0  121.0
#           2014      0.0   6904.0      0.0  4735.0      0.0  12755.0  106.0
# 33        2012      0.0      0.0  49546.0     0.0  73049.0      0.0    0.0
#           2013      0.0      0.0  31725.0     0.0  67802.0      0.0    0.0
#           2014      0.0      0.0  20315.0     0.0  49052.0      0.0    0.0
#
# item_nbr         85     91     92     93      109
# store_nbr year
# 21        2012   0.0  242.0    0.0    0.0     0.0
#           2013   0.0  253.0    0.0    0.0   710.0
# ...

# %%
df2 = station.pivot_table(index='item_nbr', columns=['year','store_nbr'], values='units', aggfunc=np.sum)

# %%
df2 = df2.replace(0,np.nan)

# %%
df4= df2.dropna(how='all', axis=0)

# %%
df4.fillna(value=0, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3035: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df4
# Out:
# year          2012                       2013                       2014  \
# store_nbr       21       29       33       21       29       33       21
# item_nbr
# 5          16100.0      0.0      0.0  15868.0      0.0      0.0   9673.0
# 8              0.0  12969.0      0.0      0.0  10472.0      0.0      0.0
# 9              0.0      0.0  49546.0      0.0      0.0  31725.0      0.0
# 41             0.0   9290.0      0.0      0.0   6571.0      0.0      0.0
# 44         29364.0      0.0  73049.0  24776.0      0.0  67802.0  15449.0
# 45             0.0  27185.0      0.0      0.0  18863.0      0.0      0.0
# 56             0.0    325.0      0.0      0.0    121.0      0.0      0.0
# 85             0.0      0.0     61.0      0.0      0.0     14.0      0.0
# 91           242.0      0.0      0.0    253.0      0.0      0.0    105.0
# 92             0.0      0.0    424.0      0.0      0.0    140.0      0.0
# 93             0.0      0.0    273.0      0.0      0.0     55.0      0.0
# ...

# %%
df3.plot.bar()
plt.show()

# %%
station.plot(x='date', y='tavg')
plt.show()

# %%
station.plot(x='date', y='heat')
plt.show()

# %%
station.plot(x='date', y='cool')
plt.show()
