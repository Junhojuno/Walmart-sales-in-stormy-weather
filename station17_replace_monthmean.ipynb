# %%
weather = weather = pd.read_csv("weather_imputation.csv")

station = weather[weather['station_nbr'] == 17]
station.reset_index(drop=True, inplace=True)
station.tail()
# Out:
#       station_nbr        date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 1030           17  2014-10-27  82.0  67.0  75.0     NaN      57.0     63.0
# 1031           17  2014-10-28  70.0  45.0  58.0     NaN      44.0     51.0
# 1032           17  2014-10-29  73.0  39.0  56.0     NaN      42.0     48.0
# 1033           17  2014-10-30  77.0  43.0  60.0     NaN      41.0     50.0
# 1034           17  2014-10-31  59.0  34.0  47.0     NaN      32.0     41.0
#
#       heat  cool ...   snowfall  preciptotal stnpressure  sealevel  \
# 1030   0.0  10.0 ...        0.0         0.05       29.11     29.77
# 1031   7.0   0.0 ...        0.0         0.04       29.45     30.11
# 1032   9.0   0.0 ...        0.0         0.00       29.50     30.19
# 1033   5.0   0.0 ...        0.0         0.00       29.45     30.14
# 1034  18.0   0.0 ...        0.0         0.00       29.72     30.39
#
#       resultspeed  resultdir  avgspeed  year  month  day
# 1030          8.7       20.0      10.8  2014     10   27
# 1031          3.9        2.0       4.8  2014     10   28
# 1032          0.9       19.0       1.4  2014     10   29
# 1033          2.6       32.0       5.1  2014     10   30
# 1034          9.2        1.0       9.3  2014     10   31
#
# [5 rows x 23 columns]

# %%
station['date'] = pd.to_datetime(station['date'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 1 ( 0.1 % )
# tmin : 1 ( 0.1 % )
# tavg : 5 ( 0.48 % )
# depart : 1035 ( 100.0 % )
# dewpoint : 1 ( 0.1 % )
# wetbulb : 9 ( 0.87 % )
# heat : 5 ( 0.48 % )
# cool : 5 ( 0.48 % )
# sunrise : 1035 ( 100.0 % )
# sunset : 1035 ( 100.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 55 ( 5.31 % )
# preciptotal : 1 ( 0.1 % )
# stnpressure : 2 ( 0.19 % )
# sealevel : 11 ( 1.06 % )
# resultspeed : 4 ( 0.39 % )
# resultdir : 4 ( 0.39 % )
# avgspeed : 1 ( 0.1 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %% [markdown]
# ##### finding : tavg, heat, cool
# - tavg = (tmin + tmax) / 2
# - 65 - heat = tavg
# - 65 + cool = tavg

# %% [markdown]
# ##### tmax와 tmin의 평균을 tavg에 넣어준다.

# %%
# tmax와 tmin의 평균을 tavg에 넣어준다.
station['tavg'] = (station.tmax + station.tmin) / 2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ##### heat = 65 - tavg 대입

# %%
# heat = 65 - tavg
idx = station[station.heat.isna()].index
station.loc[idx,'heat'] = 65 - station.loc[idx,'tavg']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ##### # cool = tavg - 65

# %%
# cool = tavg - 65
idx = station[station.cool.isna()].index
station.loc[idx,'cool'] = station.loc[idx,'tavg'] - 65
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 1 ( 0.1 % )
# tmin : 1 ( 0.1 % )
# tavg : 1 ( 0.1 % )
# depart : 1035 ( 100.0 % )
# dewpoint : 1 ( 0.1 % )
# wetbulb : 9 ( 0.87 % )
# heat : 1 ( 0.1 % )
# cool : 1 ( 0.1 % )
# sunrise : 1035 ( 100.0 % )
# sunset : 1035 ( 100.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 55 ( 5.31 % )
# preciptotal : 1 ( 0.1 % )
# stnpressure : 2 ( 0.19 % )
# sealevel : 11 ( 1.06 % )
# resultspeed : 4 ( 0.39 % )
# resultdir : 4 ( 0.39 % )
# avgspeed : 1 ( 0.1 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %% [markdown]
# #### NaN값 : 해당 월의 평균값을 집어넣는다.
# - column의 index를 뽑는다.
# - index의 year와 month를 뽑는다.
# - 해당 nan값의 year, month column평균을 낸다.
# - 적용 후 tavg, heat, cool을 구한다.

# %%
# idxs = station[station['depart'].isna().values].index
# year = station.loc[idxs[0],'year']
# month = station.loc[idxs[0],'month']
# year, month

# %%
# ym = station[station['year']==year][station['month']==month]
# station.loc[idxs[0],'depart'] = ym['depart'].mean()

# %% [markdown]
# ### 여러 column에 적용해보자

# %%
for column in station.columns[2:8]:
    idxs = station[station[column].isna().values].index
    for idx in idxs:
        year = station.loc[idx,'year']
        month = station.loc[idx,'month']
        ym = station[station['year']==year][station['month']==month]
        station.loc[idx,column] = ym[column].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 1035 ( 100.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 1 ( 0.1 % )
# cool : 1 ( 0.1 % )
# sunrise : 1035 ( 100.0 % )
# sunset : 1035 ( 100.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 55 ( 5.31 % )
# preciptotal : 1 ( 0.1 % )
# stnpressure : 2 ( 0.19 % )
# sealevel : 11 ( 1.06 % )
# resultspeed : 4 ( 0.39 % )
# resultdir : 4 ( 0.39 % )
# avgspeed : 1 ( 0.1 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %% [markdown]
# ##### 한번더  더해준다 : tavg, heat, cool
# - tavg = (tmin + tmax) / 2
# - 65 - heat = tavg
# - 65 + cool = tavg

# %%
# heat = 65 - tavg
idx = station[station.heat.isna()].index
station.loc[idx,'heat'] = 65 - station.loc[idx,'tavg']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ##### # cool = tavg - 65

# %%
# cool = tavg - 65
idx = station[station.cool.isna()].index
station.loc[idx,'cool'] = station.loc[idx,'tavg'] - 65
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for column in station.columns[13:18]:
    idxs = station[station[column].isna().values].index
    for idx in idxs:
        year = station.loc[idx,'year']
        month = station.loc[idx,'month']
        ym = station[station['year']==year][station['month']==month]
        station.loc[idx,column] = ym[column].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 1035 ( 100.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 0 ( 0.0 % )
# cool : 0 ( 0.0 % )
# sunrise : 1035 ( 100.0 % )
# sunset : 1035 ( 100.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 0 ( 0.0 % )
# preciptotal : 0 ( 0.0 % )
# stnpressure : 0 ( 0.0 % )
# sealevel : 0 ( 0.0 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 4 ( 0.39 % )
# avgspeed : 1 ( 0.1 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %%
for column in station.columns[19:20]:
    idxs = station[station[column].isna().values].index
    for idx in idxs:
        year = station.loc[idx,'year']
        month = station.loc[idx,'month']
        ym = station[station['year']==year][station['month']==month]
        station.loc[idx,column] = ym[column].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 1035 ( 100.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 0 ( 0.0 % )
# cool : 0 ( 0.0 % )
# sunrise : 1035 ( 100.0 % )
# sunset : 1035 ( 100.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 0 ( 0.0 % )
# preciptotal : 0 ( 0.0 % )
# stnpressure : 0 ( 0.0 % )
# sealevel : 0 ( 0.0 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 4 ( 0.39 % )
# avgspeed : 0 ( 0.0 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )

# %%
station.to_csv("station17_monthmean.csv", index=False)

# %%
cols = ['tmax','tmin','tavg','dewpoint','wetbulb','heat','cool','preciptotal','stnpressure','sealevel','resultspeed','avgspeed']
sns.pairplot(station[cols])
plt.show()
